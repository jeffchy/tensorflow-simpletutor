# %%
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data

# %%
mnist = input_data.read_data_sets("MNIST", one_hot=True)

batch_size = 100

n_batch = mnist.train.num_examples // batch_size

def weight_variable(shape):
    # [filter_height, filter_width, in_channel, out_channel]
    initial = tf.truncated_normal(shape, stddev=0.1)
    return tf.Variable(initial)

def bias_variable(shape):
    initial = tf.constant(0.1, shape=shape)
    return tf.Variable(initial)

def conv2D(x, W):
    # x input tensor [batch, height, width, in_channel]
    # W filter [filter_height, filter_width, in_channel, out_channel]
    # stride 
    # padding strategy: SAME VALUD 
    return tf.nn.conv2d(x, W, strides=[1,1,1,1], padding="SAME")

def max_pool_2x2(x):
    # ksize=(1,x,y,1)
    return tf.nn.max_pool(x, ksize=[1,2,2,1], strides=[1,2,2,1], padding="SAME")

x = tf.placeholder(tf.float32, [None, 784])
y = tf.placeholder(tf.float32, [None, 10])

x_image = tf.reshape(x, [-1,28,28,1])
W_conv1 = weight_variable([5,5,1,32])
b_conv1 = bias_variable([32])

h_conv1 = tf.nn.relu(conv2D(x_image, W_conv1)+b_conv1)
h_pool1 = max_pool_2x2(h_conv1)

W_conv2 = weight_variable([5,5,32,64])
b_conv2 = bias_variable([64]) # every conv kernel / a bias

h_conv2 = tf.nn.relu(conv2D(h_pool1, W_conv2)+b_conv2)
h_pool2 = max_pool_2x2(h_conv2)
# 7x7x64

W_fc1 = weight_variable([7*7*64, 1024])
b_fc1 = bias_variable([1024])

h_pool2_flat = tf.reshape(h_pool2, [-1, 7*7*64])
h_fc1 = tf.nn.relu(tf.matmul(h_pool2_flat, W_fc1)+b_fc1)

keep_prob = tf.placeholder(tf.float32)
h_fc1_drop = tf.nn.dropout(h_fc1, keep_prob)

W_fc2 = weight_variable([1024, 10])
b_fc2 = bias_variable([10])

prediction = tf.nn.softmax(tf.matmul(h_fc1_drop, W_fc2)+b_fc2)

correct_prediction = tf.equal(tf.argmax(prediction,1),tf.arg_max(y,1))

cross_entropy = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=y, logits=prediction))

update = tf.train.AdamOptimizer(1e-4).minimize(cross_entropy)

accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    for epoch in range(21):
        for batch in range(n_batch):
            batch_xs, batch_ys = mnist.train.next_batch(batch_size)
            sess.run(update, feed_dict={x:batch_xs, y:batch_ys, keep_prob:0.7})
            
        acc = sess.run(accuracy, feed_dict={x:mnist.test.images, y:mnist.test.labels, keep_prob:1.0})
        
        print("Iter "+str(epoch)+" , Testing accuracy= "+str(acc))
# Out:
# Extracting MNIST/train-images-idx3-ubyte.gz
# Extracting MNIST/train-labels-idx1-ubyte.gz
# Extracting MNIST/t10k-images-idx3-ubyte.gz
# Extracting MNIST/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From <ipython-input-9-844499e7ba2f>:58: arg_max (from tensorflow.python.ops.gen_math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `argmax` instead
# Iter 0 , Testing accuracy= 0.7656
# Iter 1 , Testing accuracy= 0.9689
# Iter 2 , Testing accuracy= 0.9766
# Iter 3 , Testing accuracy= 0.9803
# Iter 4 , Testing accuracy= 0.9848
# Iter 5 , Testing accuracy= 0.9865
# Iter 6 , Testing accuracy= 0.9865
# Iter 7 , Testing accuracy= 0.9869
# Iter 8 , Testing accuracy= 0.9892
# Iter 9 , Testing accuracy= 0.9891
# Iter 10 , Testing accuracy= 0.9882
# Iter 11 , Testing accuracy= 0.9912
# Iter 12 , Testing accuracy= 0.9897
# Iter 13 , Testing accuracy= 0.991
# Iter 14 , Testing accuracy= 0.9893
# Iter 15 , Testing accuracy= 0.9921
# ...

# %%
import tensorflow as tf
import numpy as np
from tqdm import tqdm

# %%
# create data
x_data = np.random.rand(100)
y_data = x_data*0.1 + 0.2

b = tf.Variable(0.)
k = tf.Variable(0.)
y = k * x_data + b

# linear regression
loss = tf.reduce_mean(tf.square(y_data - y))
optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.1)
train = optimizer.minimize(loss)

init = tf.global_variables_initializer()

with tf.Session() as sess:
    sess.run(init)
    
    for step in tqdm(range(500)):
        sess.run(train)
        if step % 20 == 0:
            print(step, sess.run([k, b]))
# Out:
# 100%|██████████| 500/500 [00:00<00:00, 4926.40it/s]
# 0 [0.02882411, 0.050611265]
# 20 [0.10788419, 0.19502483]
# 40 [0.105956875, 0.19658008]
# 60 [0.1043931, 0.19747865]
# 80 [0.10323959, 0.19814068]
# 100 [0.10238896, 0.1986289]
# 120 [0.101761684, 0.1989889]
# 140 [0.10129911, 0.19925441]
# 160 [0.100958, 0.19945018]
# 180 [0.10070644, 0.19959456]
# 200 [0.100520946, 0.19970101]
# 220 [0.10038417, 0.19977951]
# 240 [0.100283295, 0.1998374]
# 260 [0.10020892, 0.1998801]
# 280 [0.10015407, 0.19991158]
# 300 [0.100113615, 0.19993478]
# 320 [0.1000838, 0.1999519]
# 340 [0.10006181, 0.19996452]
# 360 [0.10004559, 0.19997384]
# 380 [0.100033626, 0.1999807]
# 400 [0.100024804, 0.19998577]
# 420 [0.100018285, 0.1999895]
# 440 [0.100013494, 0.19999224]
# 460 [0.10000997, 0.19999427]
# 480 [0.10000736, 0.19999577]

# %%
x_data
# Out:
# array([0.17850708, 0.84714907, 0.39318527, 0.87753191, 0.94832671,
#        0.04968919, 0.9192493 , 0.13435279, 0.7812607 , 0.16199391,
#        0.97115716, 0.47824677, 0.95056607, 0.46768771, 0.7640804 ,
#        0.1219695 , 0.32772301, 0.020141  , 0.16609467, 0.92490281,
#        0.03831078, 0.8977688 , 0.97126763, 0.20132441, 0.71064045,
#        0.31897312, 0.46162835, 0.58863   , 0.9429002 , 0.15266095,
#        0.49354032, 0.63879814, 0.68341944, 0.85275009, 0.00323394,
#        0.84058427, 0.2832013 , 0.65062053, 0.68434366, 0.60564381,
#        0.95576619, 0.60504677, 0.61478569, 0.12797005, 0.60994188,
#        0.50489498, 0.71570909, 0.54672333, 0.91279672, 0.87026888,
#        0.63050718, 0.61550895, 0.74354301, 0.9603373 , 0.96866512,
#        0.26663646, 0.7400856 , 0.77758214, 0.83523538, 0.41329936,
#        0.27091324, 0.15591715, 0.43959273, 0.55314672, 0.02171847,
#        0.91322223, 0.27993957, 0.73873134, 0.97820547, 0.94302241,
#        0.55847403, 0.16302988, 0.65456814, 0.87197702, 0.53894962,
#        0.65469144, 0.28942794, 0.71272827, 0.11006996, 0.40295208,
#        0.73821356, 0.21516353, 0.01588603, 0.90354166, 0.46611641,
#        0.03264396, 0.36234288, 0.36558006, 0.65862171, 0.79213553,
#        0.52402843, 0.85702059, 0.91610718, 0.80666831, 0.25903989,
#        0.26483204, 0.83184109, 0.55805655, 0.26203869, 0.9763167 ])
